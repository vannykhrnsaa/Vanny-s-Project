# %% [markdown]
# #Vanny Khairunnisaa (2206051506)

# %%
import pandas as pd
data = pd.read_csv ('/content/Clustering_gmm.csv')
print (data)
# Out:
#         Weight      Height
# 0    67.062924  176.086355
# 1    68.804094  178.388669
# 2    60.930863  170.284496
# 3    59.733843  168.691992
# 4    65.431230  173.763679
# ..         ...         ...
# 495  59.976983  169.679741
# 496  66.423814  174.625574
# 497  53.604698  161.919208
# 498  50.433644  160.794875
# 499  60.224392  169.689709
#
# [500 rows x 2 columns]

# %%
import pandas as pd
data = pd.read_csv('/content/Clustering_gmm.csv')

#training GMM
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
gmm = GaussianMixture(n_components=5)
gmm.fit(data)

#predictions from GMM
labels = gmm.predict (data)
frame = pd. DataFrame (data)
frame['cluster'] = labels
frame.columns = ['Weight', 'Height', 'cluster']

#plotting results
color = ['blue', 'green', 'cyan']
for k in range (0,3):
data = frame [frame ["cluster"]==k]
plt.scatter(data["Weight"],data["Height"],c=color [k])
plt.show()
# Out:
#   File "<ipython-input-54-314869283374>", line 19
#     data = frame [frame ["cluster"]==k]
#     ^
# IndentationError: expected an indented block after 'for' statement on line 18

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=3)
gmm.fit(data)

labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels
frame.columns = ['Weight', 'Height','cluster' ]

color=['blue', 'green', 'cyan']
for k in range (0,3):
  data = frame[frame["cluster"]==k]
  plt.scatter(data["Weight"],data["Height"],c=color[k])
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)

pred = kmeans.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = pred
frame.columns = ['Weight', 'Height','cluster' ]

color=['blue', 'green', 'cyan']
for k in range (0,3):
  data = frame[frame["cluster"]==k]
  plt.scatter(data["Weight"],data["Height"],c=color[k])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(data)

labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels
frame.columns = ['Weight', 'Height', 'cluster']

color = ['blue', 'green', 'cyan']
for k in range(0, 3):
    cluster_data = frame[frame["cluster"] == k]
    plt.scatter(cluster_data["Weight"], cluster_data["Height"], c=color[k])

plt.show()

# %%
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(data)

pred = kmeans.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = pred
frame.columns = ['Weight', 'Height','cluster' ]

color=['blue', 'green', 'cyan', 'black', 'yellow']
for k in range (0,5):
  data = frame[frame["cluster"]==k]
  plt.scatter(data["Weight"],data["Height"],c=color[k])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
gmm = GaussianMixture(n_components=5)
gmm.fit(data)

labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels
frame.columns = ['Weight', 'Height', 'cluster']

color = ['blue', 'green', 'cyan', 'black', 'yellow']
for k in range(0, 5):
    cluster_data = frame[frame["cluster"] == k]
    plt.scatter(cluster_data["Weight"], cluster_data["Height"], c=color[k])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-2db478f33dca> in <cell line: 2>()
#       1 gmm = GaussianMixture(n_components=5)
# ----> 2 gmm.fit(data)
#       3
#       4 labels = gmm.predict(data)
#       5 frame = pd.DataFrame(data)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/mixture/_base.py in fit(self, X, y)
#     184         """
#     185         # parameters are validated in fit_predict
# --> 186         self.fit_predict(X, y)
#     187         return self
#     188
#
# /usr/local/lib/python3.10/dist-packages/sklearn/mixture/_base.py in fit_predict(self, X, y)
#     218         X = self._validate_data(X, dtype=[np.float64, np.float32], ensure_min_samples=2)
#     219         if X.shape[0] < self.n_components:
# --> 220             raise ValueError(
#     221                 "Expected n_samples >= n_components "
#     222                 f"but got n_components = {self.n_components}, "
#
# ValueError: Expected n_samples >= n_components but got n_components = 5, n_samples = 4
